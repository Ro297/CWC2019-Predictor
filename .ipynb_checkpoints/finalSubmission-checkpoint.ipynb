# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Dropout,Conv2D
from sklearn.model_selection import train_test_split
import csv
import pandas as pd
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
# Out:
# Using TensorFlow backend.

# %%
main = pd.read_csv('Final_Dataset.csv')
team1 = pd.read_csv('Final_Dataset.csv',usecols=['Team_1'])
team2 = pd.read_csv('Final_Dataset.csv',usecols=['Team_2']).values
###ha = pd.read_csv('dataset/main.csv',usecols=['Home']).values
#One Hot encoding

team1 = encoder.fit_transform(team1)
team2 = encoder.fit_transform(team2)
###homeaway = encoder.fit_transform(ha)

oneHot = np.append(team1,team2,axis=1)

# %%
#Loading stats
#Preparing Data
statistics = pd.read_csv('Final_Dataset.csv')
statistics = statistics[['T1_score','T1_wickets','T1_overs','T1_rpo','T2_score','T2_wickets','T2_overs','T2_rpo']].values
statistics = np.append(oneHot,statistics,axis=1)
#Output data
winLoss =  pd.read_csv('Final_Dataset.csv',usecols=['T1_result']).values
winLoss = encoder.fit_transform(winLoss)

X_train, X_test, y_train, y_test = train_test_split(statistics, winLoss, test_size=0.20)

# %%
#MODEL
model = Sequential()
keras.optimizers.adam(lr=0.1)

model.add(Dense(30, activation='relu',input_dim=28))
model.add(Dropout(0.30))
model.add(Dense(25, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(np.asarray(X_train),np.asarray(y_train), epochs=50)
# Out:
# WARNING:tensorflow:From c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 238/238 [==============================] - 2s 9ms/step - loss: 6.1798 - acc: 0.5210
# Epoch 2/50
# 238/238 [==============================] - 0s 75us/step - loss: 4.8836 - acc: 0.5252
# Epoch 3/50
# 238/238 [==============================] - 0s 96us/step - loss: 4.5467 - acc: 0.5084
# Epoch 4/50
# 238/238 [==============================] - 0s 88us/step - loss: 4.0241 - acc: 0.5336
# Epoch 5/50
# 238/238 [==============================] - 0s 96us/step - loss: 2.2306 - acc: 0.5798
# Epoch 6/50
# 238/238 [==============================] - 0s 88us/step - loss: 2.1635 - acc: 0.5042
# Epoch 7/50
# 238/238 [==============================] - 0s 101us/step - loss: 1.9548 - acc: 0.5672
# Epoch 8/50
# 238/238 [==============================] - 0s 80us/step - loss: 1.7453 - acc: 0.5588
# Epoch 9/50
# 238/238 [==============================] - 0s 113us/step - loss: 1.9067 - acc: 0.5252
# Epoch 10/50
# 238/238 [==============================] - 0s 92us/step - loss: 1.4295 - acc: 0.5924
# Epoch 11/50
# 238/238 [==============================] - 0s 88us/step - loss: 1.4227 - acc: 0.6050
# Epoch 12/50
# 238/238 [==============================] - 0s 101us/step - loss: 1.3414 - acc: 0.6008
# Epoch 13/50
# 238/238 [==============================] - 0s 117us/step - loss: 1.1950 - acc: 0.6345
# Epoch 14/50
# 238/238 [==============================] - 0s 109us/step - loss: 1.2188 - acc: 0.6050
# Epoch 15/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.9728 - acc: 0.6303
# Epoch 16/50
# 238/238 [==============================] - 0s 113us/step - loss: 1.0841 - acc: 0.6471
# Epoch 17/50
# 238/238 [==============================] - ETA: 0s - loss: 1.0546 - acc: 0.656 - 0s 92us/step - loss: 0.9790 - acc: 0.6891
# Epoch 18/50
# 238/238 [==============================] - 0s 96us/step - loss: 0.8227 - acc: 0.7353
# Epoch 19/50
# 238/238 [==============================] - 0s 88us/step - loss: 0.7802 - acc: 0.7017
# Epoch 20/50
# 238/238 [==============================] - 0s 75us/step - loss: 0.8436 - acc: 0.6597
# Epoch 21/50
# 238/238 [==============================] - 0s 134us/step - loss: 0.7722 - acc: 0.7059
# Epoch 22/50
# 238/238 [==============================] - 0s 113us/step - loss: 0.8667 - acc: 0.7143
# Epoch 23/50
# 238/238 [==============================] - 0s 96us/step - loss: 0.5344 - acc: 0.7899
# Epoch 24/50
# 238/238 [==============================] - 0s 130us/step - loss: 0.6409 - acc: 0.7521
# Epoch 25/50
# 238/238 [==============================] - 0s 101us/step - loss: 0.6752 - acc: 0.7479
# Epoch 26/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.5587 - acc: 0.7647
# Epoch 27/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.6546 - acc: 0.7689
# Epoch 28/50
# 238/238 [==============================] - 0s 96us/step - loss: 0.5140 - acc: 0.7941
# Epoch 29/50
# 238/238 [==============================] - 0s 109us/step - loss: 0.5728 - acc: 0.7731
# Epoch 30/50
# 238/238 [==============================] - 0s 117us/step - loss: 0.4553 - acc: 0.8025
# Epoch 31/50
# 238/238 [==============================] - 0s 113us/step - loss: 0.4639 - acc: 0.8151
# Epoch 32/50
# 238/238 [==============================] - 0s 122us/step - loss: 0.4942 - acc: 0.8109
# Epoch 33/50
# 238/238 [==============================] - 0s 130us/step - loss: 0.5106 - acc: 0.7647
# Epoch 34/50
# 238/238 [==============================] - 0s 113us/step - loss: 0.4886 - acc: 0.8403
# Epoch 35/50
# 238/238 [==============================] - 0s 117us/step - loss: 0.4896 - acc: 0.8067
# Epoch 36/50
# 238/238 [==============================] - 0s 113us/step - loss: 0.4342 - acc: 0.8109
# Epoch 37/50
# 238/238 [==============================] - 0s 117us/step - loss: 0.4405 - acc: 0.8277
# Epoch 38/50
# 238/238 [==============================] - 0s 75us/step - loss: 0.4403 - acc: 0.8319
# Epoch 39/50
# 238/238 [==============================] - 0s 92us/step - loss: 0.4787 - acc: 0.8025
# Epoch 40/50
# 238/238 [==============================] - 0s 88us/step - loss: 0.4033 - acc: 0.8655
# Epoch 41/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.4546 - acc: 0.8109
# Epoch 42/50
# 238/238 [==============================] - 0s 101us/step - loss: 0.3750 - acc: 0.8487
# Epoch 43/50
# 238/238 [==============================] - 0s 92us/step - loss: 0.4324 - acc: 0.8193
# Epoch 44/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.4477 - acc: 0.8529
# Epoch 45/50
# 238/238 [==============================] - 0s 96us/step - loss: 0.4510 - acc: 0.8277
# Epoch 46/50
# 238/238 [==============================] - 0s 67us/step - loss: 0.4049 - acc: 0.8361
# Epoch 47/50
# 238/238 [==============================] - 0s 88us/step - loss: 0.4440 - acc: 0.8487
# Epoch 48/50
# 238/238 [==============================] - 0s 63us/step - loss: 0.4013 - acc: 0.8739
# Epoch 49/50
# 238/238 [==============================] - 0s 84us/step - loss: 0.3514 - acc: 0.8613
# Epoch 50/50
# 238/238 [==============================] - 0s 75us/step - loss: 0.4016 - acc: 0.8445

# %%
#Testing
print(model.evaluate(X_test,y_test))
model.summary()
# Out:
# 60/60 [==============================] - 0s 3ms/step
# [0.3355171720186869, 0.8833333452542623]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 30)                870
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                775
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                260
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,916
# Trainable params: 1,916
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(history.history['acc'])
plt.title('Model Accuracy on Training')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.show()

# %%
#CLI UI
while(True):
#NEED TO LOAD DATA AGAIN!
    stats = pd.read_csv('Final_Dataset.csv')
    home = pd.read_csv('Final_Dataset.csv',usecols=['Team_1'])
    away = pd.read_csv('Final_Dataset.csv',usecols=['Team_2']).values
    home = encoder.fit_transform(home)
    away = encoder.fit_transform(away)


    t1 = input("Enter team batting first: ")
    t2 = input("Enter team batting second: ")

    #Finding the row where these teams match
    location = stats.loc[(stats['Team_1']==t1) & (stats['Team_2']==t2)].index
    teams = np.append(home[location[0]],away[location[0]])
    statsPredict = stats[(stats['Team_1']==t1) & (stats['Team_2']==t2)]
    statsPredict = statsPredict[['T1_score','T1_wickets','T1_overs','T1_rpo','T2_score','T2_wickets','T2_overs','T2_rpo']].values
    statsPredict = statsPredict.mean(axis=0)
    statsPredict = np.transpose(statsPredict)
    teams = np.append(teams,statsPredict)
    #PREDICTION!!!!!
    #PRINTING
    prediction = model.predict(np.asarray([teams]))
    print(prediction)
    if(prediction>0.5):
        print(t1, "WINS")
    else:
        print(t2,"WINS")
    if(prediction>0.45 and prediction<0.55):
        print("Game will be close")
